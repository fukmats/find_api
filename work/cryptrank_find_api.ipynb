# %%
import csv # used to save the file in CSV format
import os
import pandas as pd # dataframe to hold the data
import pprint # makes it pretty
import re 
import requests # access HTTP requests

# Functions:
#  getDynamicAPI()
#  saveData(dataset)
#  checkItems(api_link)

# Make this whole code into a function and use the collection name as the argument
 


# List of Solanart Collections (maybe turn into a menu)
solanart_collections = ["sollamasgraves", "sollamas-gen2", "aurory", "degenape", "boldbadgers"]

# collection_name = "sollamas-gen2"  # change commentfor different collection
# collection_name = "sollamasgraves" #(Sollamas)
collection_name = "aurory" #(Aurory)
# collection_name = "degenape" #(Degen Ape)
# collection_name = "boldbadgers" #(Bold Badgers)

# store the attributes in a dictionary object
attribute_database = {}

# the file name is the collection name
output_file = os.getcwd() + '/{}.csv'.format(collection_name)

# Gets the API subdomain from the website (not an offical API, so no subdomain)
def getDynamicAPI():
    print("Getting dynamic api link. Please wait ...")
    link = "https://solanart.io/collections/{}".format(collection_name)
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.193 Safari/537.36'
    }
    try:
        resp = requests.get(link, headers=headers).text
    except:
        print("Failed to open {}".format(link))
        return ""

    custom_js_link = "https://solanart.io" + \
        resp.split('<script src="')[1].split('"')[0]
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.193 Safari/537.36'
    }
    try:
        resp = requests.get(custom_js_link, headers=headers).text
    except:
        print("Failed to open {}".format(link))
        return ""

    # Parse the API link from the javascript code
    api_link = re.findall(r'REACT_APP_API_NETWORK:"(.+?)"', resp)[0]
    return api_link

# Saves the data into two columns: the attribute and floor price (add a third column to show the number of NFTs listed for each, this is shown in the terminal)
def saveData(dataset):
    with open(output_file, mode='a+', encoding='utf-8', newline='') as csvFile:
        fieldnames = ["Attribute Name", "Lowest Price"]
        writer = csv.DictWriter(csvFile, fieldnames=fieldnames)
        if os.stat(output_file).st_size == 0:
            writer.writeheader()
        writer.writerow(
            {"Attribute Name": dataset[0], "Lowest Price": dataset[1]})

# Finds the floor
def checkItems(api_link):
    link = "{}/nft_for_sale?collection={}".format(
        api_link, collection_name)
    # HTTP header to make sure the website accepts our request
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.193 Safari/537.36'
    }
    # make the request from the website and convert the data into a JSON file
    try:
        # print(resp) will show all the data collected
        resp = requests.get(link, headers=headers).json()
    except:
        print("Failed to open {}".format(link))
    # all the unique names of the attriutes from Solanart
    attribute_set = set()

    

    # get the price for the individual attributes
    for item in resp:
        # gets the list of attributes (comma seperated)
        if item.get('attributes') is None:
            continue
        # seperate the attributes
        all_attributes = item.get('attributes').split(',')
        for attribute in all_attributes:
            if attribute.isdigit():
                continue
            attribute_set.add(attribute)

    # alphabetically sort the attributes  
    attribute_set = sorted(list(attribute_set))

    # manually added the collection name
    attribute_set.append("sollamasgen2")

    # loop through the attribute_set and get the lowest price for each attribute
    for attribute_name in attribute_set:
        if attribute_database.get(attribute_name) is None:
            attribute_database[attribute_name] = []

        for item in resp:
            if item.get('attributes') is None:
                continue
            all_attributes = item.get('attributes').split(',')
            if attribute_name in all_attributes:
                attribute_database[attribute_name].append(item.get('price'))
                attribute_database[attribute_name] = sorted(
                    attribute_database[attribute_name])
            if attribute_name == "sollamasgen2" and item.get('type') == attribute_name:
                attribute_database[attribute_name].append(item.get('price'))
                attribute_database[attribute_name] = sorted(
                    attribute_database[attribute_name])

    # sorts by lowest price to Highest Price in order to find the price floor
    for attribute_name in attribute_set:
        try:
            print("{}: {} [total items matched: {}]".format(attribute_name,
                                                            attribute_database.get(attribute_name, [''])[0], len(attribute_database.get(attribute_name))))
            saveData([attribute_name, attribute_database.get(
                attribute_name, [''])[0]])
        except:
            pass

# This is where the program executes
if __name__ == "__main__":
    # deletes the previous file
    if os.path.exists(output_file):
        os.remove(output_file)
    api_link = getDynamicAPI()
    checkItems(api_link)
        


# Convert CSV to Excel file format
read_file = pd.read_csv (r"{}.csv".format(collection_name))
read_file.to_excel (r'{}.xlsx'.format(collection_name), index = None, header=True) #will need to change the file name to something that is based on the collection name
# Out:
# Getting dynamic api link. Please wait ...
#  sequence: 1001: 53 [total items matched: 1]
#  sequence: 1003: 34.900002 [total items matched: 1]
#  sequence: 1005: 169 [total items matched: 1]
#  sequence: 1014: 70 [total items matched: 1]
#  sequence: 1018: 89 [total items matched: 1]
#  sequence: 105: 80 [total items matched: 1]
#  sequence: 1052: 100 [total items matched: 1]
#  sequence: 1069: 222 [total items matched: 1]
#  sequence: 1070: 52 [total items matched: 1]
#  sequence: 1072: 55 [total items matched: 1]
#  sequence: 1073: 38 [total items matched: 1]
#  sequence: 1076: 69.690002 [total items matched: 1]
#  sequence: 1079: 49.900002 [total items matched: 1]
#  sequence: 1086: 188 [total items matched: 1]
#  sequence: 1087: 17.700001 [total items matched: 1]
#  sequence: 1090: 25 [total items matched: 1]
#  sequence: 1099: 27.9 [total items matched: 1]
#  sequence: 1116: 135 [total items matched: 1]
#  sequence: 112: 44 [total items matched: 1]
#  sequence: 1120: 150 [total items matched: 1]
#  sequence: 1124: 250 [total items matched: 1]
#  sequence: 1127: 27 [total items matched: 1]
#  sequence: 1130: 65 [total items matched: 1]
#  sequence: 1138: 35 [total items matched: 1]
#  sequence: 1141: 21 [total items matched: 1]
#  sequence: 115: 200 [total items matched: 1]
#  sequence: 1161: 249 [total items matched: 1]
#  sequence: 1163: 2000 [total items matched: 1]
#  sequence: 1182: 33 [total items matched: 1]
#  sequence: 1188: 54 [total items matched: 1]
#  sequence: 1190: 149 [total items matched: 1]
#  sequence: 1196: 35 [total items matched: 1]
#  sequence: 12: 120 [total items matched: 1]
#  sequence: 1200: 20.049999 [total items matched: 1]
#  sequence: 1206: 100 [total items matched: 1]
#  sequence: 1209: 51 [total items matched: 1]
#  sequence: 1224: 23 [total items matched: 1]
#  sequence: 1228: 48.5 [total items matched: 1]
#  sequence: 1232: 23 [total items matched: 1]
#  sequence: 124: 78.989998 [total items matched: 1]
#  sequence: 1246: 48 [total items matched: 1]
#  sequence: 1251: 19.9 [total items matched: 1]
#  sequence: 1257: 135 [total items matched: 1]
#  sequence: 1259: 38 [total items matched: 1]
#  sequence: 1263: 295 [total items matched: 1]
#  sequence: 1266: 100 [total items matched: 1]
#  sequence: 1271: 55 [total items matched: 1]
#  sequence: 1273: 80 [total items matched: 1]
#  sequence: 1281: 116 [total items matched: 1]
#  sequence: 1284: 42 [total items matched: 1]
#  sequence: 1291: 75 [total items matched: 1]
#  sequence: 1298: 39.5 [total items matched: 1]
#  sequence: 1299: 31 [total items matched: 1]
#  sequence: 131: 24 [total items matched: 1]
#  sequence: 1319: 79 [total items matched: 1]
#  sequence: 1322: 23.5 [total items matched: 1]
#  sequence: 1323: 34 [total items matched: 1]
#  sequence: 1327: 25 [total items matched: 1]
#  sequence: 1331: 22 [total items matched: 1]
#  sequence: 134: 85 [total items matched: 1]
#  sequence: 1343: 90 [total items matched: 1]
#  sequence: 1345: 108 [total items matched: 1]
#  sequence: 1347: 22 [total items matched: 1]
#  sequence: 1365: 49 [total items matched: 1]
#  sequence: 1367: 19.85 [total items matched: 1]
#  sequence: 1370: 185 [total items matched: 1]
#  sequence: 1371: 22.5 [total items matched: 1]
#  sequence: 138: 138 [total items matched: 1]
#  sequence: 1380: 10000 [total items matched: 1]
#  sequence: 1381: 65 [total items matched: 1]
#  sequence: 1387: 65 [total items matched: 1]
#  sequence: 1390: 79 [total items matched: 1]
#  sequence: 1397: 500 [total items matched: 1]
#  sequence: 1398: 150 [total items matched: 1]
#  sequence: 14: 29.99 [total items matched: 1]
#  sequence: 1402: 200 [total items matched: 1]
#  sequence: 1412: 38 [total items matched: 1]
#  sequence: 1414: 79.699997 [total items matched: 1]
#  sequence: 1421: 189 [total items matched: 1]
#  sequence: 1424: 850 [total items matched: 1]
#  sequence: 1435: 50 [total items matched: 1]
#  sequence: 1448: 35 [total items matched: 1]
#  sequence: 1449: 36.799999 [total items matched: 1]
#  sequence: 1451: 25 [total items matched: 1]
#  sequence: 1454: 300 [total items matched: 1]
#  sequence: 1463: 250 [total items matched: 1]
#  sequence: 1467: 98 [total items matched: 1]
#  sequence: 1469: 164 [total items matched: 1]
#  sequence: 147: 25 [total items matched: 1]
#  sequence: 1473: 34.990002 [total items matched: 1]
#  sequence: 1479: 588 [total items matched: 1]
#  sequence: 1489: 76.699997 [total items matched: 1]
#  sequence: 1503: 17.99 [total items matched: 1]
#  sequence: 1510: 29 [total items matched: 1]
#  sequence: 1512: 29 [total items matched: 1]
#  sequence: 1513: 33.990002 [total items matched: 1]
#  sequence: 1524: 45 [total items matched: 1]
#  sequence: 1529: 32 [total items matched: 1]
#  sequence: 153: 250 [total items matched: 1]
#  sequence: 1530: 1000 [total items matched: 1]
#  sequence: 1533: 23.9 [total items matched: 1]
#  sequence: 1535: 49.900002 [total items matched: 1]
#  sequence: 1538: 107 [total items matched: 1]
#  sequence: 1539: 27 [total items matched: 1]
#  sequence: 154: 269 [total items matched: 1]
#  sequence: 1551: 397 [total items matched: 1]
#  sequence: 1554: 288 [total items matched: 1]
#  sequence: 1563: 56 [total items matched: 1]
#  sequence: 1566: 101 [total items matched: 1]
#  sequence: 1567: 25 [total items matched: 1]
#  sequence: 1580: 500 [total items matched: 1]
#  sequence: 1583: 75 [total items matched: 1]
#  sequence: 1587: 250 [total items matched: 1]
#  sequence: 1593: 27 [total items matched: 1]
#  sequence: 16: 29 [total items matched: 1]
#  sequence: 1601: 55 [total items matched: 1]
#  sequence: 1605: 22 [total items matched: 1]
#  sequence: 1608: 149 [total items matched: 1]
#  sequence: 1612: 27.9 [total items matched: 1]
#  sequence: 162: 99 [total items matched: 1]
#  sequence: 1622: 39 [total items matched: 1]
#  sequence: 1624: 44.5 [total items matched: 1]
#  sequence: 1626: 100 [total items matched: 1]
#  sequence: 1629: 180 [total items matched: 1]
#  sequence: 163: 27 [total items matched: 1]
#  sequence: 1634: 150 [total items matched: 1]
#  sequence: 1646: 25.549999 [total items matched: 1]
#  sequence: 1662: 35 [total items matched: 1]
#  sequence: 1670: 30 [total items matched: 1]
#  sequence: 1681: 69 [total items matched: 1]
#  sequence: 1682: 27 [total items matched: 1]
#  sequence: 1688: 70 [total items matched: 1]
#  sequence: 1692: 45 [total items matched: 1]
#  sequence: 1703: 39 [total items matched: 1]
#  sequence: 1716: 32 [total items matched: 1]
#  sequence: 1719: 28.5 [total items matched: 1]
#  sequence: 1720: 1088 [total items matched: 1]
#  sequence: 1722: 50 [total items matched: 1]
#  sequence: 1730: 100 [total items matched: 1]
#  sequence: 1741: 80 [total items matched: 1]
#  sequence: 1745: 125 [total items matched: 1]
#  sequence: 1747: 84 [total items matched: 1]
#  sequence: 1750: 54 [total items matched: 1]
#  sequence: 1753: 130 [total items matched: 1]
#  sequence: 1759: 150 [total items matched: 1]
#  sequence: 1765: 29 [total items matched: 1]
#  sequence: 177: 39 [total items matched: 1]
#  sequence: 178: 1000 [total items matched: 1]
#  sequence: 1796: 328 [total items matched: 1]
#  sequence: 1799: 82 [total items matched: 1]
#  sequence: 1808: 69 [total items matched: 1]
#  sequence: 1809: 20 [total items matched: 1]
#  sequence: 181: 45 [total items matched: 1]
#  sequence: 1817: 99 [total items matched: 1]
#  sequence: 1818: 130 [total items matched: 1]
#  sequence: 1821: 30 [total items matched: 1]
#  sequence: 1822: 75 [total items matched: 1]
#  sequence: 1828: 88.879997 [total items matched: 1]
#  sequence: 1832: 295 [total items matched: 1]
#  sequence: 1834: 100 [total items matched: 1]
#  sequence: 1835: 69 [total items matched: 1]
#  sequence: 1842: 17.65 [total items matched: 1]
#  sequence: 1848: 150 [total items matched: 1]
#  sequence: 1850: 750 [total items matched: 1]
#  sequence: 1852: 144 [total items matched: 1]
#  sequence: 1856: 24.799999 [total items matched: 1]
#  sequence: 1881: 34 [total items matched: 1]
#  sequence: 1882: 1000 [total items matched: 1]
#  sequence: 1884: 99 [total items matched: 1]
#  sequence: 1890: 75 [total items matched: 1]
#  sequence: 190: 71 [total items matched: 1]
#  sequence: 1901: 500 [total items matched: 1]
#  sequence: 1905: 321 [total items matched: 1]
#  sequence: 1907: 18 [total items matched: 1]
#  sequence: 1911: 90 [total items matched: 1]
#  sequence: 1922: 71 [total items matched: 1]
#  sequence: 1923: 60 [total items matched: 1]
#  sequence: 1925: 32 [total items matched: 1]
#  sequence: 1927: 45 [total items matched: 1]
#  sequence: 1929: 377.769989 [total items matched: 1]
#  sequence: 1930: 69.690002 [total items matched: 1]
#  sequence: 1936: 115 [total items matched: 1]
#  sequence: 1951: 21 [total items matched: 1]
#  sequence: 1955: 35 [total items matched: 1]
#  sequence: 1958: 80 [total items matched: 1]
#  sequence: 196: 80 [total items matched: 1]
#  sequence: 1968: 100 [total items matched: 1]
#  sequence: 1978: 140 [total items matched: 1]
#  sequence: 1980: 69 [total items matched: 1]
#  sequence: 1981: 42 [total items matched: 1]
#  sequence: 1991: 350 [total items matched: 1]
#  sequence: 1992: 100 [total items matched: 1]
#  sequence: 1997: 45 [total items matched: 1]
#  sequence: 1999: 329 [total items matched: 1]
#  sequence: 2000: 40 [total items matched: 1]
#  sequence: 2001: 20 [total items matched: 1]
#  sequence: 2003: 100 [total items matched: 1]
#  sequence: 2004: 29.5 [total items matched: 1]
#  sequence: 2008: 101 [total items matched: 1]
#  sequence: 201: 32 [total items matched: 1]
#  sequence: 2022: 69 [total items matched: 1]
#  sequence: 2026: 24.950001 [total items matched: 1]
#  sequence: 2029: 80 [total items matched: 1]
#  sequence: 2033: 60 [total items matched: 1]
#  sequence: 2042: 99 [total items matched: 1]
#  sequence: 2055: 72 [total items matched: 1]
#  sequence: 2059: 29 [total items matched: 1]
#  sequence: 2065: 130 [total items matched: 1]
#  sequence: 207: 40.5 [total items matched: 1]
#  sequence: 2080: 169 [total items matched: 1]
#  sequence: 2087: 17.99 [total items matched: 1]
#  sequence: 2090: 120 [total items matched: 1]
#  sequence: 2091: 50 [total items matched: 1]
#  sequence: 2093: 94 [total items matched: 1]
#  sequence: 2097: 40 [total items matched: 1]
#  sequence: 2102: 24 [total items matched: 1]
#  sequence: 2118: 22.700001 [total items matched: 1]
#  sequence: 2123: 100 [total items matched: 1]
#  sequence: 2132: 25 [total items matched: 1]
#  sequence: 2140: 25 [total items matched: 1]
#  sequence: 2141: 49 [total items matched: 1]
#  sequence: 2147: 50 [total items matched: 1]
#  sequence: 2153: 98 [total items matched: 1]
#  sequence: 2176: 70 [total items matched: 1]
#  sequence: 2179: 100 [total items matched: 1]
#  sequence: 219: 1 [total items matched: 4]
#  sequence: 2203: 20 [total items matched: 1]
#  sequence: 2204: 20.99 [total items matched: 1]
#  sequence: 2205: 60 [total items matched: 1]
#  sequence: 221: 14.9 [total items matched: 1]
#  sequence: 2221: 199 [total items matched: 1]
#  sequence: 2224: 70 [total items matched: 1]
#  sequence: 2230: 100 [total items matched: 1]
#  sequence: 2231: 88.888885 [total items matched: 1]
#  sequence: 2234: 27 [total items matched: 1]
#  sequence: 2247: 88 [total items matched: 1]
#  sequence: 2259: 399 [total items matched: 1]
#  sequence: 2263: 50 [total items matched: 1]
#  sequence: 2264: 200 [total items matched: 1]
#  sequence: 2267: 39 [total items matched: 1]
#  sequence: 2272: 44 [total items matched: 1]
#  sequence: 2275: 599 [total items matched: 1]
#  sequence: 2280: 60 [total items matched: 1]
#  sequence: 2288: 1000 [total items matched: 1]
#  sequence: 2293: 55 [total items matched: 1]
#  sequence: 2300: 199 [total items matched: 1]
#  sequence: 2308: 96 [total items matched: 1]
#  sequence: 2311: 60 [total items matched: 1]
#  sequence: 2314: 38 [total items matched: 1]
#  sequence: 2317: 19.99 [total items matched: 1]
#  sequence: 2325: 22.700001 [total items matched: 1]
#  sequence: 2333: 24 [total items matched: 1]
#  sequence: 2343: 58 [total items matched: 1]
#  sequence: 2345: 45 [total items matched: 1]
#  sequence: 2358: 55 [total items matched: 1]
#  sequence: 2359: 24.450001 [total items matched: 1]
#  sequence: 2369: 950 [total items matched: 1]
#  sequence: 2370: 99 [total items matched: 1]
#  sequence: 2385: 29 [total items matched: 1]
#  sequence: 2394: 75 [total items matched: 1]
#  sequence: 2418: 75 [total items matched: 1]
#  sequence: 2423: 125 [total items matched: 1]
#  sequence: 2426: 190 [total items matched: 1]
#  sequence: 2431: 70 [total items matched: 1]
#  sequence: 2436: 31 [total items matched: 1]
#  sequence: 2439: 66666 [total items matched: 1]
#  sequence: 244: 40 [total items matched: 1]
#  sequence: 2446: 599 [total items matched: 1]
#  sequence: 2449: 100 [total items matched: 1]
#  sequence: 2453: 99 [total items matched: 1]
#  sequence: 2460: 82 [total items matched: 1]
#  sequence: 2468: 888 [total items matched: 1]
#  sequence: 2473: 499 [total items matched: 1]
#  sequence: 2476: 50 [total items matched: 1]
#  sequence: 2479: 333 [total items matched: 1]
#  sequence: 2489: 50 [total items matched: 1]
#  sequence: 2490: 60 [total items matched: 1]
#  sequence: 2494: 50 [total items matched: 1]
#  sequence: 2496: 100 [total items matched: 1]
#  sequence: 2513: 100 [total items matched: 1]
#  sequence: 2514: 21 [total items matched: 1]
#  sequence: 2517: 66 [total items matched: 1]
#  sequence: 2524: 54 [total items matched: 1]
#  sequence: 2536: 56 [total items matched: 1]
#  sequence: 2538: 28000 [total items matched: 1]
#  sequence: 2540: 22 [total items matched: 1]
#  sequence: 2549: 40 [total items matched: 1]
#  sequence: 2556: 350 [total items matched: 1]
#  sequence: 2560: 99 [total items matched: 1]
#  sequence: 2565: 28 [total items matched: 1]
#  sequence: 2583: 75 [total items matched: 1]
#  sequence: 2590: 79 [total items matched: 1]
#  sequence: 2591: 92 [total items matched: 1]
#  sequence: 2604: 29.9 [total items matched: 1]
#  sequence: 2613: 69 [total items matched: 1]
#  sequence: 2618: 28 [total items matched: 1]
#  sequence: 2619: 59 [total items matched: 1]
#  sequence: 2622: 100 [total items matched: 1]
#  sequence: 2624: 35 [total items matched: 1]
#  sequence: 2636: 29.889999 [total items matched: 1]
#  sequence: 2663: 90 [total items matched: 1]
#  sequence: 2665: 999 [total items matched: 1]
#  sequence: 2667: 90 [total items matched: 1]
#  sequence: 2669: 50 [total items matched: 1]
#  sequence: 2671: 74.989998 [total items matched: 1]
#  sequence: 2675: 69 [total items matched: 1]
#  sequence: 2679: 100 [total items matched: 1]
#  sequence: 2685: 10000 [total items matched: 1]
#  sequence: 2704: 39 [total items matched: 1]
#  sequence: 2713: 26.799999 [total items matched: 1]
#  sequence: 2724: 39.5 [total items matched: 1]
#  sequence: 2733: 224 [total items matched: 1]
#  sequence: 2735: 28 [total items matched: 1]
#  sequence: 2737: 55 [total items matched: 1]
#  sequence: 2741: 399 [total items matched: 1]
#  sequence: 2743: 29 [total items matched: 1]
#  sequence: 2754: 55 [total items matched: 1]
#  sequence: 2756: 123.400002 [total items matched: 1]
#  sequence: 2761: 99 [total items matched: 1]
#  sequence: 2779: 37 [total items matched: 1]
#  sequence: 2784: 34 [total items matched: 1]
#  sequence: 2785: 200 [total items matched: 1]
#  sequence: 279: 50 [total items matched: 1]
#  sequence: 2801: 49 [total items matched: 1]
#  sequence: 2803: 67 [total items matched: 1]
#  sequence: 2805: 19 [total items matched: 1]
#  sequence: 2807: 60 [total items matched: 1]
#  sequence: 2811: 27 [total items matched: 1]
#  sequence: 2813: 140 [total items matched: 1]
#  sequence: 2816: 42.069 [total items matched: 1]
#  sequence: 2818: 250 [total items matched: 1]
#  sequence: 2819: 380 [total items matched: 1]
#  sequence: 2825: 50 [total items matched: 1]
#  sequence: 2836: 149 [total items matched: 1]
#  sequence: 2838: 52 [total items matched: 1]
#  sequence: 2842: 95 [total items matched: 1]
#  sequence: 2848: 69 [total items matched: 1]
#  sequence: 285: 140 [total items matched: 1]
#  sequence: 2853: 388 [total items matched: 1]
#  sequence: 2861: 100 [total items matched: 1]
#  sequence: 2862: 488 [total items matched: 1]
#  sequence: 2866: 98 [total items matched: 1]
#  sequence: 2867: 99.699997 [total items matched: 1]
#  sequence: 2879: 35 [total items matched: 1]
#  sequence: 2880: 51 [total items matched: 1]
#  sequence: 2881: 27 [total items matched: 1]
#  sequence: 2885: 29 [total items matched: 1]
#  sequence: 2888: 59.689999 [total items matched: 1]
#  sequence: 2894: 33 [total items matched: 1]
#  sequence: 2899: 25 [total items matched: 1]
#  sequence: 2906: 82 [total items matched: 1]
#  sequence: 2907: 100 [total items matched: 1]
#  sequence: 2919: 27.4 [total items matched: 1]
#  sequence: 2924: 64 [total items matched: 1]
#  sequence: 2930: 134.444 [total items matched: 1]
#  sequence: 2939: 44 [total items matched: 1]
#  sequence: 2945: 46 [total items matched: 1]
#  sequence: 2946: 45 [total items matched: 1]
#  sequence: 295: 42 [total items matched: 1]
#  sequence: 2950: 88 [total items matched: 1]
#  sequence: 2955: 30 [total items matched: 1]
#  sequence: 2963: 28 [total items matched: 1]
#  sequence: 2968: 59 [total items matched: 1]
#  sequence: 297: 19 [total items matched: 2]
#  sequence: 2971: 185 [total items matched: 1]
#  sequence: 2976: 69.999001 [total items matched: 1]
#  sequence: 2978: 90 [total items matched: 1]
#  sequence: 2979: 39.999001 [total items matched: 1]
#  sequence: 298: 24.9 [total items matched: 1]
#  sequence: 2989: 540 [total items matched: 1]
#  sequence: 2997: 197 [total items matched: 1]
#  sequence: 3004: 30 [total items matched: 1]
#  sequence: 3021: 99.800003 [total items matched: 1]
#  sequence: 3026: 79 [total items matched: 1]
#  sequence: 3027: 150 [total items matched: 1]
#  sequence: 3035: 50 [total items matched: 1]
#  sequence: 3042: 20 [total items matched: 1]
#  sequence: 3048: 19 [total items matched: 1]
#  sequence: 3055: 137 [total items matched: 1]
#  sequence: 3056: 275 [total items matched: 1]
#  sequence: 3057: 58 [total items matched: 1]
#  sequence: 3068: 135 [total items matched: 1]
#  sequence: 3071: 65 [total items matched: 1]
#  sequence: 3072: 22.5 [total items matched: 1]
#  sequence: 3077: 64 [total items matched: 1]
#  sequence: 3079: 75 [total items matched: 1]
#  sequence: 308: 500 [total items matched: 1]
#  sequence: 3081: 373 [total items matched: 1]
#  sequence: 3083: 150 [total items matched: 1]
#  sequence: 3091: 442 [total items matched: 1]
#  sequence: 3098: 36 [total items matched: 1]
#  sequence: 310: 30 [total items matched: 1]
#  sequence: 3103: 100 [total items matched: 1]
#  sequence: 3104: 50 [total items matched: 1]
#  sequence: 3111: 277 [total items matched: 1]
#  sequence: 3127: 111 [total items matched: 1]
#  sequence: 3135: 69 [total items matched: 1]
#  sequence: 3139: 149 [total items matched: 1]
#  sequence: 3150: 100 [total items matched: 1]
#  sequence: 3157: 294.940002 [total items matched: 1]
#  sequence: 3161: 75 [total items matched: 1]
#  sequence: 3172: 26 [total items matched: 1]
#  sequence: 3189: 21.9 [total items matched: 1]
#  sequence: 3213: 35 [total items matched: 1]
#  sequence: 3215: 90 [total items matched: 1]
#  sequence: 3217: 99 [total items matched: 1]
#  sequence: 3222: 800 [total items matched: 1]
#  sequence: 3223: 28 [total items matched: 1]
#  sequence: 3225: 25 [total items matched: 1]
#  sequence: 3230: 75 [total items matched: 1]
#  sequence: 3239: 25 [total items matched: 1]
#  sequence: 3240: 149 [total items matched: 1]
#  sequence: 3256: 114 [total items matched: 1]
#  sequence: 3257: 100 [total items matched: 1]
#  sequence: 3260: 29.99 [total items matched: 1]
#  sequence: 3276: 95 [total items matched: 1]
#  sequence: 328: 20 [total items matched: 1]
#  sequence: 3280: 55 [total items matched: 1]
#  sequence: 3293: 199 [total items matched: 1]
#  sequence: 3306: 111 [total items matched: 1]
#  sequence: 3310: 177 [total items matched: 1]
#  sequence: 3312: 130 [total items matched: 1]
#  sequence: 3320: 83 [total items matched: 1]
#  sequence: 3322: 350 [total items matched: 1]
#  sequence: 333: 333 [total items matched: 1]
#  sequence: 3333: 333.299988 [total items matched: 1]
#  sequence: 3344: 69.419998 [total items matched: 1]
#  sequence: 3348: 42 [total items matched: 1]
#  sequence: 3349: 23 [total items matched: 1]
#  sequence: 3362: 28 [total items matched: 1]
#  sequence: 3385: 99.989998 [total items matched: 1]
#  sequence: 34: 220 [total items matched: 1]
#  sequence: 3401: 28.5 [total items matched: 1]
#  sequence: 3403: 33 [total items matched: 1]
#  sequence: 341: 1800 [total items matched: 1]
#  sequence: 3416: 64 [total items matched: 1]
#  sequence: 3417: 249 [total items matched: 1]
#  sequence: 3418: 21 [total items matched: 1]
#  sequence: 3420: 99.900002 [total items matched: 1]
#  sequence: 3441: 98.800003 [total items matched: 1]
#  sequence: 3444: 50 [total items matched: 1]
#  sequence: 3447: 17.9 [total items matched: 1]
#  sequence: 3451: 50 [total items matched: 1]
#  sequence: 3452: 300 [total items matched: 1]
#  sequence: 346: 27 [total items matched: 1]
#  sequence: 3462: 35 [total items matched: 1]
#  sequence: 3463: 59 [total items matched: 1]
#  sequence: 3464: 111 [total items matched: 1]
#  sequence: 3465: 50 [total items matched: 1]
#  sequence: 3470: 500 [total items matched: 1]
#  sequence: 3473: 20 [total items matched: 1]
#  sequence: 3481: 1001 [total items matched: 1]
#  sequence: 3498: 29.99 [total items matched: 1]
#  sequence: 3499: 42 [total items matched: 1]
#  sequence: 35: 100 [total items matched: 1]
#  sequence: 3503: 21.25 [total items matched: 1]
#  sequence: 3508: 19.4 [total items matched: 1]
#  sequence: 3516: 48 [total items matched: 1]
#  sequence: 352: 54 [total items matched: 1]
#  sequence: 3524: 60 [total items matched: 1]
#  sequence: 3529: 27.799999 [total items matched: 1]
#  sequence: 3536: 19.9 [total items matched: 1]
#  sequence: 3537: 29 [total items matched: 1]
#  sequence: 354: 37 [total items matched: 1]
#  sequence: 3545: 29 [total items matched: 1]
#  sequence: 3551: 26 [total items matched: 1]
#  sequence: 3568: 49 [total items matched: 1]
#  sequence: 3570: 400 [total items matched: 1]
#  sequence: 3572: 47.5 [total items matched: 1]
#  sequence: 3575: 125 [total items matched: 1]
#  sequence: 3581: 65 [total items matched: 1]
#  sequence: 3587: 123 [total items matched: 1]
#  sequence: 3589: 49 [total items matched: 1]
#  sequence: 3590: 75 [total items matched: 1]
#  sequence: 3593: 49.990002 [total items matched: 1]
#  sequence: 3596: 69.690002 [total items matched: 1]
#  sequence: 3597: 28 [total items matched: 1]
#  sequence: 3605: 95 [total items matched: 1]
#  sequence: 362: 25 [total items matched: 1]
#  sequence: 3623: 69 [total items matched: 1]
#  sequence: 3628: 30 [total items matched: 1]
#  sequence: 3632: 40 [total items matched: 1]
#  sequence: 3635: 398 [total items matched: 1]
#  sequence: 3640: 369 [total items matched: 1]
#  sequence: 3647: 100 [total items matched: 1]
#  sequence: 3653: 23 [total items matched: 1]
#  sequence: 3659: 999 [total items matched: 1]
#  sequence: 3663: 120 [total items matched: 1]
#  sequence: 3674: 75 [total items matched: 1]
#  sequence: 3675: 165 [total items matched: 1]
#  sequence: 3678: 24.9 [total items matched: 1]
#  sequence: 3679: 65 [total items matched: 1]
#  sequence: 368: 120 [total items matched: 1]
#  sequence: 3686: 300 [total items matched: 1]
#  sequence: 3687: 1000 [total items matched: 1]
#  sequence: 3691: 60 [total items matched: 1]
#  sequence: 3701: 599 [total items matched: 1]
#  sequence: 3705: 20 [total items matched: 1]
#  sequence: 3711: 25 [total items matched: 1]
#  sequence: 3716: 27 [total items matched: 1]
#  sequence: 3718: 147 [total items matched: 1]
#  sequence: 3719: 38 [total items matched: 1]
#  sequence: 3727: 39 [total items matched: 1]
#  sequence: 373: 95 [total items matched: 1]
#  sequence: 3739: 49 [total items matched: 1]
#  sequence: 3745: 29.5 [total items matched: 1]
#  sequence: 3749: 138 [total items matched: 1]
#  sequence: 3750: 35 [total items matched: 1]
#  sequence: 3756: 97 [total items matched: 1]
#  sequence: 3758: 288 [total items matched: 1]
#  sequence: 3762: 100 [total items matched: 1]
#  sequence: 3769: 33 [total items matched: 1]
#  sequence: 3770: 49 [total items matched: 1]
#  sequence: 3776: 75 [total items matched: 1]
#  sequence: 3787: 27 [total items matched: 1]
#  sequence: 3792: 33 [total items matched: 1]
#  sequence: 3798: 500 [total items matched: 1]
#  sequence: 3805: 60 [total items matched: 1]
#  sequence: 3808: 9876 [total items matched: 1]
#  sequence: 381: 250 [total items matched: 1]
#  sequence: 3814: 39 [total items matched: 1]
#  sequence: 382: 99 [total items matched: 1]
#  sequence: 3820: 52 [total items matched: 1]
#  sequence: 3825: 49 [total items matched: 1]
#  sequence: 3826: 79 [total items matched: 1]
#  sequence: 3827: 50 [total items matched: 1]
#  sequence: 3830: 69 [total items matched: 1]
#  sequence: 3848: 98 [total items matched: 1]
#  sequence: 385: 290 [total items matched: 1]
#  sequence: 3854: 148 [total items matched: 1]
#  sequence: 3859: 200 [total items matched: 1]
#  sequence: 3860: 98 [total items matched: 1]
#  sequence: 3867: 90 [total items matched: 1]
#  sequence: 3870: 18 [total items matched: 1]
#  sequence: 3871: 108 [total items matched: 1]
#  sequence: 3877: 39.950001 [total items matched: 1]
#  sequence: 3885: 100 [total items matched: 1]
#  sequence: 3892: 42 [total items matched: 1]
#  sequence: 3895: 28 [total items matched: 1]
#  sequence: 3899: 420 [total items matched: 1]
#  sequence: 39: 23.950001 [total items matched: 1]
#  sequence: 3902: 100 [total items matched: 1]
#  sequence: 3910: 29.99 [total items matched: 1]
#  sequence: 3917: 240 [total items matched: 1]
#  sequence: 3930: 35 [total items matched: 1]
#  sequence: 3947: 21.5 [total items matched: 1]
#  sequence: 3965: 25 [total items matched: 1]
#  sequence: 3966: 50 [total items matched: 1]
#  sequence: 397: 600 [total items matched: 1]
#  sequence: 3972: 29 [total items matched: 1]
#  sequence: 3973: 21 [total items matched: 1]
#  sequence: 3976: 30 [total items matched: 1]
#  sequence: 3980: 22.690001 [total items matched: 1]
#  sequence: 3983: 88 [total items matched: 1]
#  sequence: 3984: 188.888794 [total items matched: 1]
#  sequence: 3989: 42 [total items matched: 1]
#  sequence: 399: 150 [total items matched: 1]
#  sequence: 4002: 50 [total items matched: 1]
#  sequence: 4004: 69.989998 [total items matched: 1]
#  sequence: 4006: 50 [total items matched: 1]
#  sequence: 4007: 100 [total items matched: 1]
#  sequence: 401: 65 [total items matched: 1]
#  sequence: 4013: 88.879997 [total items matched: 1]
#  sequence: 4015: 90 [total items matched: 1]
#  sequence: 403: 110 [total items matched: 1]
#  sequence: 4033: 40 [total items matched: 1]
#  sequence: 4042: 60 [total items matched: 1]
#  sequence: 4044: 800 [total items matched: 1]
#  sequence: 4047: 100 [total items matched: 1]
#  sequence: 4055: 98 [total items matched: 1]
#  sequence: 407: 39 [total items matched: 1]
#  sequence: 4071: 333 [total items matched: 1]
#  sequence: 4074: 128 [total items matched: 1]
#  sequence: 4075: 31 [total items matched: 1]
#  sequence: 4078: 27 [total items matched: 1]
#  sequence: 4079: 30 [total items matched: 1]
#  sequence: 4081: 555 [total items matched: 1]
#  sequence: 4087: 27 [total items matched: 1]
#  sequence: 4091: 88.900002 [total items matched: 1]
#  sequence: 4092: 22 [total items matched: 1]
#  sequence: 4094: 100 [total items matched: 1]
#  sequence: 4096: 130 [total items matched: 1]
#  sequence: 4097: 980 [total items matched: 1]
#  sequence: 4099: 100 [total items matched: 1]
#  sequence: 4115: 688 [total items matched: 1]
#  sequence: 4117: 169 [total items matched: 1]
#  sequence: 4120: 78 [total items matched: 1]
#  sequence: 4121: 65 [total items matched: 1]
#  sequence: 4139: 63 [total items matched: 1]
#  sequence: 4141: 80 [total items matched: 1]
#  sequence: 4145: 75 [total items matched: 1]
#  sequence: 4149: 82 [total items matched: 1]
#  sequence: 4156: 40.200001 [total items matched: 1]
#  sequence: 4172: 999 [total items matched: 1]
#  sequence: 4174: 32 [total items matched: 1]
#  sequence: 4179: 27 [total items matched: 1]
#  sequence: 418: 19 [total items matched: 1]
#  sequence: 4180: 23.389999 [total items matched: 1]
#  sequence: 4182: 39 [total items matched: 1]
#  sequence: 4185: 125 [total items matched: 1]
#  sequence: 420: 42 [total items matched: 1]
#  sequence: 4205: 50 [total items matched: 1]
#  sequence: 4210: 48 [total items matched: 1]
#  sequence: 4213: 700 [total items matched: 1]
#  sequence: 4230: 95 [total items matched: 1]
#  sequence: 4236: 25.9 [total items matched: 1]
#  sequence: 4238: 188 [total items matched: 1]
#  sequence: 424: 24.799999 [total items matched: 1]
#  sequence: 4245: 99 [total items matched: 1]
#  sequence: 4248: 35 [total items matched: 1]
#  sequence: 4264: 65 [total items matched: 1]
#  sequence: 4272: 200 [total items matched: 1]
#  sequence: 4274: 500 [total items matched: 1]
#  sequence: 4280: 75 [total items matched: 1]
#  sequence: 4283: 100 [total items matched: 1]
#  sequence: 4284: 19 [total items matched: 1]
#  sequence: 4287: 350 [total items matched: 1]
#  sequence: 43: 55 [total items matched: 1]
#  sequence: 4305: 33.5 [total items matched: 1]
#  sequence: 431: 165 [total items matched: 1]
#  sequence: 4311: 80 [total items matched: 1]
#  sequence: 432: 99 [total items matched: 1]
#  sequence: 4321: 87 [total items matched: 1]
#  sequence: 4331: 1000 [total items matched: 1]
#  sequence: 4342: 42 [total items matched: 1]
#  sequence: 4376: 22.799999 [total items matched: 1]
#  sequence: 4378: 60 [total items matched: 1]
#  sequence: 4396: 42 [total items matched: 1]
#  sequence: 441: 50 [total items matched: 1]
#  sequence: 4413: 72 [total items matched: 1]
#  sequence: 4414: 88.879997 [total items matched: 1]
#  sequence: 4420: 79.5 [total items matched: 1]
#  sequence: 4432: 27 [total items matched: 1]
#  sequence: 4433: 66 [total items matched: 1]
#  sequence: 4437: 29 [total items matched: 1]
#  sequence: 4441: 500 [total items matched: 1]
#  sequence: 4450: 21.5 [total items matched: 1]
#  sequence: 4452: 53 [total items matched: 1]
#  sequence: 4458: 28.5 [total items matched: 1]
#  sequence: 4465: 80 [total items matched: 1]
#  sequence: 4470: 17.799999 [total items matched: 1]
#  sequence: 4479: 190 [total items matched: 1]
#  sequence: 4487: 2.4 [total items matched: 2]
#  sequence: 4488: 27.5 [total items matched: 1]
#  sequence: 4489: 33.5 [total items matched: 1]
#  sequence: 4492: 60 [total items matched: 1]
#  sequence: 4499: 99.989998 [total items matched: 1]
#  sequence: 4502: 525 [total items matched: 1]
#  sequence: 4506: 39 [total items matched: 1]
#  sequence: 4514: 29.5 [total items matched: 1]
#  sequence: 4515: 31 [total items matched: 1]
#  sequence: 4516: 49 [total items matched: 1]
#  sequence: 452: 69.690002 [total items matched: 1]
#  sequence: 4524: 34.990002 [total items matched: 1]
#  sequence: 4534: 29 [total items matched: 1]
#  sequence: 4541: 888 [total items matched: 1]
#  sequence: 4542: 29.799999 [total items matched: 1]
#  sequence: 4545: 37 [total items matched: 1]
#  sequence: 455: 44 [total items matched: 1]
#  sequence: 4565: 43 [total items matched: 1]
#  sequence: 4576: 85 [total items matched: 1]
#  sequence: 4577: 58 [total items matched: 1]
#  sequence: 4586: 199 [total items matched: 1]
#  sequence: 459: 399 [total items matched: 1]
#  sequence: 4594: 50 [total items matched: 1]
#  sequence: 4602: 28.9 [total items matched: 1]
#  sequence: 4604: 170 [total items matched: 1]
#  sequence: 4605: 277 [total items matched: 1]
#  sequence: 4627: 45 [total items matched: 1]
#  sequence: 4628: 60 [total items matched: 1]
#  sequence: 4642: 30 [total items matched: 1]
#  sequence: 4645: 2000 [total items matched: 1]
#  sequence: 4651: 111.690002 [total items matched: 1]
#  sequence: 4657: 10000 [total items matched: 1]
#  sequence: 4658: 58.799999 [total items matched: 1]
#  sequence: 4659: 39 [total items matched: 1]
#  sequence: 4675: 50 [total items matched: 1]
#  sequence: 4691: 1000 [total items matched: 1]
#  sequence: 4693: 76 [total items matched: 1]
#  sequence: 4702: 49 [total items matched: 1]
#  sequence: 4703: 35 [total items matched: 1]
#  sequence: 4707: 24.888 [total items matched: 1]
#  sequence: 4712: 65 [total items matched: 1]
#  sequence: 4714: 56 [total items matched: 1]
#  sequence: 4718: 27 [total items matched: 1]
#  sequence: 472: 200 [total items matched: 1]
#  sequence: 4726: 67 [total items matched: 1]
#  sequence: 4730: 150 [total items matched: 1]
#  sequence: 4732: 23.98 [total items matched: 1]
#  sequence: 4748: 135 [total items matched: 1]
#  sequence: 4754: 26 [total items matched: 1]
#  sequence: 4761: 23 [total items matched: 1]
#  sequence: 4762: 195 [total items matched: 1]
#  sequence: 4770: 60 [total items matched: 1]
#  sequence: 4773: 55 [total items matched: 1]
#  sequence: 4790: 52 [total items matched: 1]
#  sequence: 4793: 120 [total items matched: 1]
#  sequence: 4796: 24.49 [total items matched: 1]
#  sequence: 4803: 30 [total items matched: 1]
#  sequence: 4806: 93 [total items matched: 1]
#  sequence: 4811: 79.5 [total items matched: 1]
#  sequence: 4816: 999 [total items matched: 1]
#  sequence: 4824: 21.9 [total items matched: 1]
#  sequence: 4828: 69.5 [total items matched: 1]
#  sequence: 4845: 89 [total items matched: 1]
#  sequence: 4852: 35 [total items matched: 1]
#  sequence: 4865: 150 [total items matched: 1]
#  sequence: 4869: 45 [total items matched: 1]
#  sequence: 4891: 149 [total items matched: 1]
#  sequence: 4895: 40 [total items matched: 1]
#  sequence: 4911: 16.5 [total items matched: 1]
#  sequence: 4916: 40 [total items matched: 1]
#  sequence: 4918: 37.5 [total items matched: 1]
#  sequence: 4921: 150 [total items matched: 1]
#  sequence: 4933: 550 [total items matched: 1]
#  sequence: 4943: 99 [total items matched: 1]
#  sequence: 4948: 24.690001 [total items matched: 1]
#  sequence: 4959: 5000 [total items matched: 1]
#  sequence: 496: 1200 [total items matched: 1]
#  sequence: 4965: 31.5 [total items matched: 1]
#  sequence: 4968: 38 [total items matched: 1]
#  sequence: 4969: 225 [total items matched: 1]
#  sequence: 4970: 250 [total items matched: 1]
#  sequence: 4977: 37 [total items matched: 1]
#  sequence: 4978: 28 [total items matched: 1]
#  sequence: 5004: 100 [total items matched: 1]
#  sequence: 501: 199 [total items matched: 1]
#  sequence: 5014: 90 [total items matched: 1]
#  sequence: 5016: 77 [total items matched: 1]
#  sequence: 5026: 40 [total items matched: 1]
#  sequence: 5037: 105 [total items matched: 1]
#  sequence: 5041: 150 [total items matched: 1]
#  sequence: 5044: 150 [total items matched: 1]
#  sequence: 5048: 49 [total items matched: 1]
#  sequence: 5066: 69 [total items matched: 1]
#  sequence: 5067: 75 [total items matched: 1]
#  sequence: 5068: 800 [total items matched: 1]
#  sequence: 5069: 90 [total items matched: 1]
#  sequence: 5073: 40 [total items matched: 1]
#  sequence: 5076: 40 [total items matched: 1]
#  sequence: 5082: 129 [total items matched: 1]
#  sequence: 5098: 25 [total items matched: 1]
#  sequence: 51: 38 [total items matched: 1]
#  sequence: 5103: 1500 [total items matched: 1]
#  sequence: 5105: 499 [total items matched: 1]
#  sequence: 5109: 188.880005 [total items matched: 1]
#  sequence: 5114: 150 [total items matched: 1]
#  sequence: 5121: 119 [total items matched: 1]
#  sequence: 513: 55.900002 [total items matched: 1]
#  sequence: 5134: 55 [total items matched: 1]
#  sequence: 5138: 28 [total items matched: 1]
#  sequence: 5144: 70 [total items matched: 1]
#  sequence: 5149: 150 [total items matched: 1]
#  sequence: 5158: 88 [total items matched: 1]
#  sequence: 516: 411 [total items matched: 1]
#  sequence: 5163: 40 [total items matched: 1]
#  sequence: 5165: 70 [total items matched: 1]
#  sequence: 5179: 45 [total items matched: 1]
#  sequence: 5182: 80 [total items matched: 1]
#  sequence: 5196: 48 [total items matched: 1]
#  sequence: 5209: 99 [total items matched: 1]
#  sequence: 5220: 175 [total items matched: 1]
#  sequence: 5225: 25 [total items matched: 1]
#  sequence: 5230: 32.900002 [total items matched: 1]
#  sequence: 5237: 220 [total items matched: 1]
#  sequence: 5242: 100 [total items matched: 1]
#  sequence: 5250: 151 [total items matched: 1]
#  sequence: 5264: 23.9 [total items matched: 1]
#  sequence: 5270: 99 [total items matched: 1]
#  sequence: 5273: 69 [total items matched: 1]
#  sequence: 5275: 247 [total items matched: 1]
#  sequence: 5277: 250 [total items matched: 1]
#  sequence: 5280: 10000 [total items matched: 1]
#  sequence: 529: 3000 [total items matched: 1]
#  sequence: 5290: 49 [total items matched: 1]
#  sequence: 5298: 55 [total items matched: 1]
#  sequence: 5300: 188 [total items matched: 1]
#  sequence: 5301: 32.900002 [total items matched: 1]
#  sequence: 5315: 140 [total items matched: 1]
#  sequence: 5320: 120 [total items matched: 1]
#  sequence: 5321: 68 [total items matched: 1]
#  sequence: 5327: 29 [total items matched: 1]
#  sequence: 5331: 125 [total items matched: 1]
#  sequence: 5337: 26.799999 [total items matched: 1]
#  sequence: 5339: 27 [total items matched: 1]
#  sequence: 5346: 188 [total items matched: 1]
#  sequence: 5347: 29 [total items matched: 1]
#  sequence: 5354: 5354 [total items matched: 1]
#  sequence: 5358: 30 [total items matched: 1]
#  sequence: 5359: 130 [total items matched: 1]
#  sequence: 536: 53 [total items matched: 1]
#  sequence: 5368: 220 [total items matched: 1]
#  sequence: 5370: 270 [total items matched: 1]
#  sequence: 5373: 450 [total items matched: 1]
#  sequence: 5376: 21.200001 [total items matched: 1]
#  sequence: 5378: 188 [total items matched: 1]
#  sequence: 5380: 49.900002 [total items matched: 1]
#  sequence: 5385: 50 [total items matched: 1]
#  sequence: 539: 17.9 [total items matched: 1]
#  sequence: 5391: 24.200001 [total items matched: 1]
#  sequence: 5397: 25 [total items matched: 1]
#  sequence: 5400: 196 [total items matched: 1]
#  sequence: 5402: 39 [total items matched: 1]
#  sequence: 5411: 43.5 [total items matched: 1]
#  sequence: 5414: 25 [total items matched: 1]
#  sequence: 5432: 23.299999 [total items matched: 1]
#  sequence: 5437: 100 [total items matched: 1]
#  sequence: 5439: 69 [total items matched: 1]
#  sequence: 5447: 61 [total items matched: 1]
#  sequence: 5451: 99.989998 [total items matched: 1]
#  sequence: 5452: 999 [total items matched: 1]
#  sequence: 5465: 64.400002 [total items matched: 1]
#  sequence: 547: 18 [total items matched: 1]
#  sequence: 5472: 25.9 [total items matched: 1]
#  sequence: 5473: 88888 [total items matched: 1]
#  sequence: 5476: 499 [total items matched: 1]
#  sequence: 5479: 54 [total items matched: 1]
#  sequence: 548: 79 [total items matched: 1]
#  sequence: 5493: 999 [total items matched: 1]
#  sequence: 5498: 1000 [total items matched: 1]
#  sequence: 5499: 70 [total items matched: 1]
#  sequence: 5507: 100 [total items matched: 1]
#  sequence: 5514: 130 [total items matched: 1]
#  sequence: 5522: 399 [total items matched: 1]
#  sequence: 5524: 31 [total items matched: 1]
#  sequence: 5531: 79 [total items matched: 1]
#  sequence: 5533: 500 [total items matched: 1]
#  sequence: 5537: 200 [total items matched: 1]
#  sequence: 5542: 33.330002 [total items matched: 1]
#  sequence: 5553: 30 [total items matched: 1]
#  sequence: 5560: 29 [total items matched: 1]
#  sequence: 557: 35 [total items matched: 1]
#  sequence: 5573: 40 [total items matched: 1]
#  sequence: 558: 24.9 [total items matched: 1]
#  sequence: 5593: 59 [total items matched: 1]
#  sequence: 560: 33.330002 [total items matched: 1]
#  sequence: 5607: 80 [total items matched: 1]
#  sequence: 5612: 35 [total items matched: 1]
#  sequence: 5618: 59 [total items matched: 1]
#  sequence: 5630: 99 [total items matched: 1]
#  sequence: 5631: 333 [total items matched: 1]
#  sequence: 5634: 45 [total items matched: 1]
#  sequence: 5639: 66 [total items matched: 1]
#  sequence: 5641: 149 [total items matched: 1]
#  sequence: 5645: 38 [total items matched: 1]
#  sequence: 5646: 46.689999 [total items matched: 1]
#  sequence: 5658: 49.990002 [total items matched: 1]
#  sequence: 5659: 350 [total items matched: 1]
#  sequence: 5668: 24.99 [total items matched: 1]
#  sequence: 5671: 22 [total items matched: 1]
#  sequence: 5680: 1000 [total items matched: 1]
#  sequence: 5681: 49 [total items matched: 1]
#  sequence: 5682: 249 [total items matched: 1]
#  sequence: 5696: 90 [total items matched: 1]
#  sequence: 5697: 3 [total items matched: 2]
#  sequence: 5698: 25 [total items matched: 1]
#  sequence: 5704: 50 [total items matched: 1]
#  sequence: 5706: 698 [total items matched: 1]
#  sequence: 5707: 64 [total items matched: 1]
#  sequence: 5709: 38 [total items matched: 1]
#  sequence: 5710: 30 [total items matched: 1]
#  sequence: 5713: 30 [total items matched: 1]
#  sequence: 5718: 280 [total items matched: 1]
#  sequence: 5720: 27.5 [total items matched: 1]
#  sequence: 5724: 66 [total items matched: 1]
#  sequence: 5738: 19.5 [total items matched: 1]
#  sequence: 5752: 38 [total items matched: 1]
#  sequence: 5754: 26 [total items matched: 1]
#  sequence: 5767: 125 [total items matched: 1]
#  sequence: 5770: 99.5 [total items matched: 1]
#  sequence: 5772: 100 [total items matched: 1]
#  sequence: 578: 190 [total items matched: 1]
#  sequence: 5782: 120 [total items matched: 1]
#  sequence: 5787: 32.689999 [total items matched: 1]
#  sequence: 5788: 49.5 [total items matched: 1]
#  sequence: 5798: 21 [total items matched: 1]
#  sequence: 580: 30 [total items matched: 1]
#  sequence: 5805: 59 [total items matched: 1]
#  sequence: 5807: 33 [total items matched: 1]
#  sequence: 5816: 350 [total items matched: 1]
#  sequence: 5817: 86 [total items matched: 1]
#  sequence: 583: 500 [total items matched: 1]
#  sequence: 5856: 40 [total items matched: 1]
#  sequence: 5860: 44 [total items matched: 1]
#  sequence: 5868: 999 [total items matched: 1]
#  sequence: 588: 1100 [total items matched: 1]
#  sequence: 5888: 85 [total items matched: 1]
#  sequence: 5891: 550 [total items matched: 1]
#  sequence: 5893: 73.900002 [total items matched: 1]
#  sequence: 5910: 40 [total items matched: 1]
#  sequence: 5915: 38 [total items matched: 1]
#  sequence: 5919: 4000 [total items matched: 1]
#  sequence: 5929: 24.6 [total items matched: 1]
#  sequence: 5943: 31.950001 [total items matched: 1]
#  sequence: 5944: 55 [total items matched: 1]
#  sequence: 5949: 50 [total items matched: 1]
#  sequence: 5964: 411.110992 [total items matched: 1]
#  sequence: 5969: 350 [total items matched: 1]
#  sequence: 5974: 199 [total items matched: 1]
#  sequence: 5979: 140 [total items matched: 1]
#  sequence: 5989: 69.900002 [total items matched: 1]
#  sequence: 5990: 68 [total items matched: 1]
#  sequence: 5993: 170 [total items matched: 1]
#  sequence: 6000: 62 [total items matched: 1]
#  sequence: 6001: 3000 [total items matched: 1]
#  sequence: 6004: 575 [total items matched: 1]
#  sequence: 6007: 69 [total items matched: 1]
#  sequence: 6018: 100 [total items matched: 1]
#  sequence: 6028: 24 [total items matched: 1]
#  sequence: 6029: 22.799999 [total items matched: 1]
#  sequence: 6030: 19.5 [total items matched: 1]
#  sequence: 6042: 42 [total items matched: 1]
#  sequence: 6071: 1250 [total items matched: 1]
#  sequence: 6073: 20 [total items matched: 1]
#  sequence: 6080: 30 [total items matched: 1]
#  sequence: 6084: 600 [total items matched: 1]
#  sequence: 609: 28.5 [total items matched: 1]
#  sequence: 6091: 40 [total items matched: 1]
#  sequence: 6109: 55 [total items matched: 1]
#  sequence: 6112: 144.444443 [total items matched: 1]
#  sequence: 6119: 99 [total items matched: 1]
#  sequence: 6128: 50 [total items matched: 1]
#  sequence: 6131: 68.5 [total items matched: 1]
#  sequence: 6149: 20 [total items matched: 1]
#  sequence: 6151: 40 [total items matched: 1]
#  sequence: 6175: 55 [total items matched: 1]
#  sequence: 6177: 60 [total items matched: 1]
#  sequence: 6179: 100 [total items matched: 1]
#  sequence: 6180: 60 [total items matched: 1]
#  sequence: 6181: 350 [total items matched: 1]
#  sequence: 6184: 39 [total items matched: 1]
#  sequence: 6187: 40.5 [total items matched: 1]
#  sequence: 6188: 128 [total items matched: 1]
#  sequence: 619: 25.5 [total items matched: 1]
#  sequence: 6194: 200 [total items matched: 1]
#  sequence: 620: 200 [total items matched: 1]
#  sequence: 6201: 30 [total items matched: 1]
#  sequence: 6204: 125 [total items matched: 1]
#  sequence: 6213: 100 [total items matched: 1]
#  sequence: 6217: 67 [total items matched: 1]
#  sequence: 6223: 35 [total items matched: 1]
#  sequence: 6235: 187 [total items matched: 1]
#  sequence: 6241: 20 [total items matched: 1]
#  sequence: 6244: 200 [total items matched: 1]
#  sequence: 6245: 67.5 [total items matched: 1]
#  sequence: 6261: 50 [total items matched: 1]
#  sequence: 6269: 40 [total items matched: 1]
#  sequence: 6272: 180 [total items matched: 1]
#  sequence: 6287: 79 [total items matched: 1]
#  sequence: 6289: 30 [total items matched: 1]
#  sequence: 6292: 46.75 [total items matched: 1]
#  sequence: 6294: 90 [total items matched: 1]
#  sequence: 6311: 2888 [total items matched: 1]
#  sequence: 6315: 99 [total items matched: 1]
#  sequence: 6334: 36.970001 [total items matched: 1]
#  sequence: 6344: 20 [total items matched: 1]
#  sequence: 6347: 45 [total items matched: 1]
#  sequence: 6349: 88 [total items matched: 1]
#  sequence: 6355: 99 [total items matched: 1]
#  sequence: 6374: 99 [total items matched: 1]
#  sequence: 6382: 169 [total items matched: 1]
#  sequence: 6384: 50 [total items matched: 1]
#  sequence: 6393: 60 [total items matched: 1]
#  sequence: 6394: 23.9 [total items matched: 1]
#  sequence: 6397: 100 [total items matched: 1]
#  sequence: 64: 60 [total items matched: 1]
#  sequence: 6402: 140 [total items matched: 1]
#  sequence: 6404: 39 [total items matched: 1]
#  sequence: 6407: 49 [total items matched: 1]
#  sequence: 6410: 35 [total items matched: 1]
#  sequence: 6414: 50 [total items matched: 1]
#  sequence: 6423: 50 [total items matched: 1]
#  sequence: 6429: 37 [total items matched: 1]
#  sequence: 6436: 49.900002 [total items matched: 1]
#  sequence: 6441: 29 [total items matched: 1]
#  sequence: 6448: 33 [total items matched: 1]
#  sequence: 6462: 239 [total items matched: 1]
#  sequence: 6470: 35 [total items matched: 1]
#  sequence: 6479: 2021 [total items matched: 1]
#  sequence: 6491: 17.93 [total items matched: 1]
#  sequence: 6500: 24 [total items matched: 1]
#  sequence: 6501: 200 [total items matched: 1]
#  sequence: 651: 69 [total items matched: 1]
#  sequence: 6518: 39 [total items matched: 1]
#  sequence: 6519: 48.48 [total items matched: 1]
#  sequence: 6520: 222 [total items matched: 1]
#  sequence: 6525: 130 [total items matched: 1]
#  sequence: 6526: 150 [total items matched: 1]
#  sequence: 6530: 25 [total items matched: 1]
#  sequence: 6542: 65 [total items matched: 1]
#  sequence: 6546: 175 [total items matched: 1]
#  sequence: 6550: 58 [total items matched: 1]
#  sequence: 6555: 55 [total items matched: 1]
#  sequence: 6558: 85 [total items matched: 1]
#  sequence: 6561: 89 [total items matched: 1]
#  sequence: 6562: 30 [total items matched: 1]
#  sequence: 6565: 36 [total items matched: 1]
#  sequence: 6575: 23.200001 [total items matched: 1]
#  sequence: 6580: 45 [total items matched: 1]
#  sequence: 6583: 59 [total items matched: 1]
#  sequence: 6587: 325 [total items matched: 1]
#  sequence: 6589: 25.5 [total items matched: 1]
#  sequence: 6592: 88.879997 [total items matched: 1]
#  sequence: 6594: 10000 [total items matched: 1]
#  sequence: 6598: 188 [total items matched: 1]
#  sequence: 6599: 330 [total items matched: 1]
#  sequence: 66: 59 [total items matched: 1]
#  sequence: 6603: 68 [total items matched: 1]
#  sequence: 6605: 55 [total items matched: 1]
#  sequence: 6619: 98.970001 [total items matched: 1]
#  sequence: 6624: 99 [total items matched: 1]
#  sequence: 6635: 70 [total items matched: 1]
#  sequence: 6636: 30 [total items matched: 1]
#  sequence: 6639: 22 [total items matched: 1]
#  sequence: 6645: 100 [total items matched: 1]
#  sequence: 665: 25.5 [total items matched: 1]
#  sequence: 6650: 29 [total items matched: 1]
#  sequence: 6654: 44 [total items matched: 1]
#  sequence: 6660: 38.599998 [total items matched: 1]
#  sequence: 6663: 23.9 [total items matched: 1]
#  sequence: 6670: 166 [total items matched: 1]
#  sequence: 6672: 55 [total items matched: 1]
#  sequence: 6674: 68 [total items matched: 1]
#  sequence: 6687: 150 [total items matched: 1]
#  sequence: 6690: 200 [total items matched: 1]
#  sequence: 67: 99 [total items matched: 1]
#  sequence: 6702: 26.5 [total items matched: 1]
#  sequence: 6711: 133 [total items matched: 1]
#  sequence: 6718: 100 [total items matched: 1]
#  sequence: 6719: 39 [total items matched: 1]
#  sequence: 6726: 75 [total items matched: 1]
#  sequence: 6727: 77.769997 [total items matched: 1]
#  sequence: 6733: 100 [total items matched: 1]
#  sequence: 6747: 29 [total items matched: 1]
#  sequence: 6755: 188 [total items matched: 1]
#  sequence: 6756: 42 [total items matched: 1]
#  sequence: 6769: 249 [total items matched: 1]
#  sequence: 6776: 27.9 [total items matched: 1]
#  sequence: 678: 35 [total items matched: 1]
#  sequence: 6783: 25 [total items matched: 1]
#  sequence: 6787: 29.860001 [total items matched: 1]
# ...
#  sequence: 9152: 33 [total items matched: 1]
#  sequence: 9156: 47 [total items matched: 1]
#  sequence: 9160: 55 [total items matched: 1]
#  sequence: 9172: 49 [total items matched: 1]
#  sequence: 9184: 75 [total items matched: 1]
#  sequence: 9185: 100 [total items matched: 1]
#  sequence: 9192: 6900 [total items matched: 1]
#  sequence: 9201: 217 [total items matched: 1]
#  sequence: 9203: 100 [total items matched: 1]
#  sequence: 9212: 182 [total items matched: 1]
#  sequence: 9214: 24 [total items matched: 1]
#  sequence: 9215: 1000 [total items matched: 1]
#  sequence: 9219: 269 [total items matched: 1]
#  sequence: 9232: 29.9 [total items matched: 1]
#  sequence: 9239: 350 [total items matched: 1]
#  sequence: 924: 70 [total items matched: 1]
#  sequence: 9240: 120 [total items matched: 1]
#  sequence: 9245: 23 [total items matched: 1]
#  sequence: 9250: 34 [total items matched: 1]
#  sequence: 9259: 40 [total items matched: 1]
#  sequence: 9264: 25 [total items matched: 1]
#  sequence: 9270: 99 [total items matched: 1]
#  sequence: 9277: 120 [total items matched: 1]
#  sequence: 9280: 58.900002 [total items matched: 1]
#  sequence: 9286: 81 [total items matched: 1]
#  sequence: 9290: 33.333302 [total items matched: 1]
#  sequence: 9292: 20 [total items matched: 1]
#  sequence: 9296: 690 [total items matched: 1]
#  sequence: 93: 34 [total items matched: 1]
#  sequence: 9305: 80 [total items matched: 1]
#  sequence: 9306: 1888 [total items matched: 1]
#  sequence: 9307: 250 [total items matched: 1]
#  sequence: 9313: 76 [total items matched: 1]
#  sequence: 9315: 9999 [total items matched: 1]
#  sequence: 9319: 94 [total items matched: 1]
#  sequence: 9323: 420 [total items matched: 1]
#  sequence: 9329: 333 [total items matched: 1]
#  sequence: 9332: 169 [total items matched: 1]
#  sequence: 9347: 30.5 [total items matched: 1]
#  sequence: 935: 34 [total items matched: 1]
#  sequence: 9353: 45 [total items matched: 1]
#  sequence: 9355: 35 [total items matched: 1]
#  sequence: 9358: 50 [total items matched: 1]
#  sequence: 936: 49 [total items matched: 1]
#  sequence: 9364: 44.950001 [total items matched: 1]
#  sequence: 9366: 69.900002 [total items matched: 1]
#  sequence: 9368: 198 [total items matched: 1]
#  sequence: 9375: 39.900002 [total items matched: 1]
#  sequence: 9384: 197 [total items matched: 1]
#  sequence: 9388: 797 [total items matched: 1]
#  sequence: 9395: 147 [total items matched: 1]
#  sequence: 9401: 70 [total items matched: 1]
#  sequence: 9402: 28.5 [total items matched: 1]
#  sequence: 9403: 100 [total items matched: 1]
#  sequence: 9430: 36.5 [total items matched: 1]
#  sequence: 944: 169 [total items matched: 1]
#  sequence: 9441: 29 [total items matched: 1]
#  sequence: 946: 22 [total items matched: 1]
#  sequence: 9462: 500 [total items matched: 1]
#  sequence: 9476: 98 [total items matched: 1]
#  sequence: 9485: 850 [total items matched: 1]
#  sequence: 9493: 1000 [total items matched: 1]
#  sequence: 9497: 425 [total items matched: 1]
#  sequence: 9501: 88 [total items matched: 1]
#  sequence: 9510: 69 [total items matched: 1]
#  sequence: 952: 29.99 [total items matched: 1]
#  sequence: 9538: 68 [total items matched: 1]
#  sequence: 9540: 65 [total items matched: 1]
#  sequence: 9544: 800 [total items matched: 1]
#  sequence: 9548: 46 [total items matched: 1]
#  sequence: 9559: 55 [total items matched: 1]
#  sequence: 9560: 33.689999 [total items matched: 1]
#  sequence: 9569: 69 [total items matched: 1]
#  sequence: 9580: 1199 [total items matched: 1]
#  sequence: 9581: 22 [total items matched: 1]
#  sequence: 9588: 88 [total items matched: 1]
#  sequence: 9591: 100 [total items matched: 1]
#  sequence: 9594: 80 [total items matched: 1]
#  sequence: 9596: 79.900002 [total items matched: 1]
#  sequence: 9599: 1069 [total items matched: 1]
#  sequence: 9600: 30 [total items matched: 1]
#  sequence: 9607: 500 [total items matched: 1]
#  sequence: 9609: 95 [total items matched: 1]
#  sequence: 9612: 29 [total items matched: 1]
#  sequence: 9614: 55 [total items matched: 1]
#  sequence: 9620: 80 [total items matched: 1]
#  sequence: 9627: 9999 [total items matched: 1]
#  sequence: 9630: 22 [total items matched: 1]
#  sequence: 9636: 150 [total items matched: 1]
#  sequence: 9637: 27.5 [total items matched: 1]
#  sequence: 964: 29 [total items matched: 1]
#  sequence: 965: 39 [total items matched: 1]
#  sequence: 9650: 199 [total items matched: 1]
#  sequence: 9651: 65 [total items matched: 1]
#  sequence: 966: 75 [total items matched: 1]
#  sequence: 9665: 27.98 [total items matched: 1]
#  sequence: 9685: 150 [total items matched: 1]
#  sequence: 9691: 28 [total items matched: 1]
#  sequence: 9698: 498 [total items matched: 1]
#  sequence: 970: 43 [total items matched: 1]
#  sequence: 9700: 21.549999 [total items matched: 1]
#  sequence: 9707: 44 [total items matched: 1]
#  sequence: 9723: 322 [total items matched: 1]
#  sequence: 9736: 50 [total items matched: 1]
#  sequence: 9741: 139 [total items matched: 1]
#  sequence: 9753: 18 [total items matched: 1]
#  sequence: 9755: 50 [total items matched: 1]
#  sequence: 9757: 70 [total items matched: 1]
#  sequence: 9759: 100 [total items matched: 1]
#  sequence: 9762: 90 [total items matched: 1]
#  sequence: 9767: 55 [total items matched: 1]
#  sequence: 9773: 225 [total items matched: 1]
#  sequence: 9774: 85 [total items matched: 1]
#  sequence: 978: 400 [total items matched: 1]
#  sequence: 9786: 80 [total items matched: 1]
#  sequence: 9787: 99 [total items matched: 1]
#  sequence: 9788: 26.9 [total items matched: 1]
#  sequence: 9792: 23 [total items matched: 1]
#  sequence: 9794: 27.950001 [total items matched: 1]
#  sequence: 9795: 100 [total items matched: 1]
#  sequence: 9801: 200 [total items matched: 1]
#  sequence: 9803: 90 [total items matched: 1]
#  sequence: 9808: 100 [total items matched: 1]
#  sequence: 9815: 30 [total items matched: 1]
#  sequence: 9816: 56 [total items matched: 1]
#  sequence: 9823: 60 [total items matched: 1]
#  sequence: 9829: 55 [total items matched: 1]
#  sequence: 9837: 49 [total items matched: 1]
#  sequence: 9844: 100 [total items matched: 1]
#  sequence: 9848: 2000 [total items matched: 1]
#  sequence: 9859: 230 [total items matched: 1]
#  sequence: 986: 100 [total items matched: 1]
#  sequence: 9872: 210 [total items matched: 1]
#  sequence: 9873: 5000 [total items matched: 1]
#  sequence: 9880: 60 [total items matched: 1]
#  sequence: 9888: 125 [total items matched: 1]
#  sequence: 9904: 98.75 [total items matched: 1]
#  sequence: 9905: 77 [total items matched: 1]
#  sequence: 991: 79 [total items matched: 1]
#  sequence: 9917: 25.5 [total items matched: 1]
#  sequence: 9919: 69 [total items matched: 1]
#  sequence: 9920: 129 [total items matched: 1]
#  sequence: 9924: 100 [total items matched: 1]
#  sequence: 9940: 22.5 [total items matched: 1]
#  sequence: 9941: 27.5 [total items matched: 1]
#  sequence: 9950: 999 [total items matched: 1]
#  sequence: 9951: 88.800003 [total items matched: 1]
#  sequence: 9952: 500 [total items matched: 1]
#  sequence: 996: 996 [total items matched: 1]
#  sequence: 9961: 800 [total items matched: 1]
#  sequence: 9978: 25 [total items matched: 1]
#  sequence: 9979: 49 [total items matched: 1]
#  sequence: 9982: 1699 [total items matched: 1]
#  sequence: 9983: 5000 [total items matched: 1]
#  sequence: 9985: 695 [total items matched: 1]
#  sequence: 9986: 1499 [total items matched: 1]
#  sequence: 9987: 5000 [total items matched: 1]
#  sequence: 9990: 2250 [total items matched: 1]
#  sequence: 9991: 2280 [total items matched: 1]
#  sequence: 9992: 5555 [total items matched: 1]
#  sequence: 9994: 2000 [total items matched: 1]
# Background: Base Background: 1 [total items matched: 1232]
# Background: Blue: 29 [total items matched: 33]
# Background: Gradient Blue: 2.4 [total items matched: 147]
# Background: Lagoon: 21 [total items matched: 31]
# Background: Mallow Gradient: 5000 [total items matched: 1]
# Background: Soft Blue: 17.940001 [total items matched: 206]
# Background: Special Blue: 1499 [total items matched: 2]
# Background: Special Orange: 2280 [total items matched: 1]
# Cloth: Axobubble Outfit: 69 [total items matched: 15]
# Cloth: Base Cloth: 2.4 [total items matched: 590]
# Cloth: Beetlefox Outfit: 1 [total items matched: 12]
# Cloth: Bitebit Outfit: 55 [total items matched: 10]
# Cloth: Black Hoodie: 20 [total items matched: 64]
# Cloth: Black T-Shirt: 19 [total items matched: 57]
# Cloth: Classic Jacket: 27 [total items matched: 17]
# Cloth: Classy Outfit: 17.700001 [total items matched: 63]
# Cloth: Dinobit Outfit: 69 [total items matched: 12]
# Cloth: Dipking Outfit: 59 [total items matched: 8]
# Cloth: Dracurve Outfit: 81 [total items matched: 9]
# Cloth: FTX US Shirt: 5000 [total items matched: 1]
# Cloth: Green Sweater: 24.99 [total items matched: 25]
# Cloth: Hawaii Shirt: 29.99 [total items matched: 27]
# Cloth: Helios Black Overalls: 2000 [total items matched: 2]
# Cloth: Helios Outfit: 45 [total items matched: 13]
# Cloth: Jacket: 14.9 [total items matched: 55]
# Cloth: Jean Jacket: 17.65 [total items matched: 75]
# Cloth: Leather Jacket: 19.99 [total items matched: 70]
# Cloth: Open Jacket: 230 [total items matched: 12]
# Cloth: Open Leather Jacket: 369 [total items matched: 4]
# Cloth: Overalls: 17.9 [total items matched: 78]
# Cloth: Pink Stripes: 17.99 [total items matched: 53]
# Cloth: Polo: 19 [total items matched: 58]
# Cloth: Puffy Jacket: 17.889999 [total items matched: 74]
# Cloth: Sam Outfit: 150 [total items matched: 10]
# Cloth: Scarf : 329 [total items matched: 4]
# Cloth: Shoulder Straps: 27 [total items matched: 29]
# Cloth: Unika Outfit: 16.5 [total items matched: 11]
# Cloth: Yellow Stripes: 20 [total items matched: 81]
# Cloth: Zzoo Outfit: 86 [total items matched: 12]
# Eyes: Aave Glasses: 14.9 [total items matched: 78]
# Eyes: Aurory Glasses: 30 [total items matched: 31]
# Eyes: Base Eyes: 1 [total items matched: 508]
# Eyes: Black Eyes: 17.700001 [total items matched: 69]
# Eyes: Blue Skull Glasses: 17.940001 [total items matched: 68]
# Eyes: Cat Black Pupil: 27.950001 [total items matched: 29]
# Eyes: Cat Eyes Black: 29 [total items matched: 17]
# Eyes: Cat Eyes Red: 20 [total items matched: 44]
# Eyes: Cat Green Pupil: 20 [total items matched: 37]
# Eyes: Green : 17.99 [total items matched: 70]
# Eyes: Green Eyes: 21 [total items matched: 68]
# Eyes: Heart Glasses: 3 [total items matched: 74]
# Eyes: Helios Cyan Blue: 2000 [total items matched: 1]
# Eyes: Helios Purple: 5555 [total items matched: 1]
# Eyes: Red Eyes: 17.65 [total items matched: 144]
# Eyes: Spring Glasses: 20 [total items matched: 34]
# Eyes: Steampunk Glasses: 21.25 [total items matched: 57]
# Eyes: Viper Shades: 16.5 [total items matched: 130]
# Hair: Blob Hair: 3 [total items matched: 62]
# Hair: Blond Hair Attached: 20 [total items matched: 40]
# Hair: Brown Dreadlocks : 19.799999 [total items matched: 32]
# Hair: Clementine Hair: 16.5 [total items matched: 47]
# Hair: Combed Haircut: 19.99 [total items matched: 93]
# Hair: Curly : 17.889999 [total items matched: 71]
# Hair: Curly Black: 5000 [total items matched: 1]
# Hair: Green Hair: 17.700001 [total items matched: 71]
# Hair: Helios Purple Hair: 5555 [total items matched: 1]
# Hair: Helios White Hair: 2000 [total items matched: 1]
# Hair: Long Blob Hair: 59.689999 [total items matched: 34]
# Hair: Pigtails: 18 [total items matched: 65]
# Hair: Playmobil : 21.200001 [total items matched: 74]
# Hair: Purple Dreadlocks: 17.700001 [total items matched: 38]
# Hair: Shaved: 19 [total items matched: 78]
# Hair: Undercut: 17.9 [total items matched: 67]
# Hair: White Hair: 29.799999 [total items matched: 22]
# Hair: Zero Two Hair: 1 [total items matched: 53]
# Hat: Axobubble Hat: 200 [total items matched: 6]
# Hat: Beetlefox Hat: 99 [total items matched: 7]
# Hat: Beret Hat: 14.9 [total items matched: 62]
# Hat: Big Crown: 17.99 [total items matched: 54]
# Hat: Bitebit Hat: 70 [total items matched: 11]
# Hat: Crazy Horse Hat: 125 [total items matched: 7]
# Hat: Crown : 17.93 [total items matched: 63]
# Hat: Cute headphone: 16.5 [total items matched: 47]
# Hat: Dinobit Hat: 129 [total items matched: 8]
# Hat: Dipking Hat: 195 [total items matched: 4]
# Hat: Doughnut Hat: 20 [total items matched: 35]
# Hat: Dracurve Hat: 119 [total items matched: 5]
# Hat: Dragon Hat: 50 [total items matched: 17]
# Hat: FTX US Cap: 5000 [total items matched: 1]
# Hat: Feather Hat: 21.75 [total items matched: 41]
# Hat: Gavroche Hat: 20.99 [total items matched: 30]
# Hat: Helios Hat: 210 [total items matched: 4]
# Hat: Jotaro Cap: 45 [total items matched: 13]
# Hat: Luffy Hat: 2.4 [total items matched: 24]
# Hat: Moogle : 30 [total items matched: 19]
# Hat: Phantom Cap: 20 [total items matched: 45]
# Hat: Plague Hat: 21.200001 [total items matched: 35]
# Hat: Raccoon Hat: 19.4 [total items matched: 40]
# Hat: Sam Hat: 32 [total items matched: 23]
# Hat: Twitter Hat: 19 [total items matched: 42]
# Hat: Unika Hat: 575 [total items matched: 2]
# Hat: Witch Hat: 23 [total items matched: 31]
# Hat: Zzoo Hat: 149 [total items matched: 8]
# Mouth: Angry : 22.5 [total items matched: 37]
# Mouth: Bane Mask: 17.99 [total items matched: 77]
# Mouth: Barely Angry: 19.5 [total items matched: 50]
# Mouth: Base Mouth: 1 [total items matched: 640]
# Mouth: Big Smile: 18 [total items matched: 102]
# Mouth: Cat Mask: 17.9 [total items matched: 139]
# Mouth: Grin: 19 [total items matched: 117]
# Mouth: Lollipop : 17.940001 [total items matched: 51]
# Mouth: Oni Mask: 19 [total items matched: 58]
# Mouth: Paint Mask: 18.99 [total items matched: 51]
# Mouth: Plague Mask: 14.9 [total items matched: 106]
# Mouth: Steampunk Mask: 17.9 [total items matched: 63]
# Mouth: Zipper Mask: 16.5 [total items matched: 148]
# Necklace: Aurory Necklace: 1 [total items matched: 584]
# Necklace: Flower Necklace: 2.4 [total items matched: 134]
# Necklace: Helios Purple Cape: 2000 [total items matched: 2]
# Necklace: Shark Necklace: 3 [total items matched: 187]
# Necklace: Solana Necklace: 18 [total items matched: 97]
# Skin: Golden Blob: 14.9 [total items matched: 14]
# Skin: Helios Black Fur: 5555 [total items matched: 1]
# Skin: Helios Cat: 2000 [total items matched: 1]
# Skin: Human: 1 [total items matched: 1376]
# Skin: Skeleton: 350 [total items matched: 6]
# Skin: Solana Blob: 35 [total items matched: 219]
# Skin: Zombie: 100 [total items matched: 36]
# Type: Aurorian: 1 [total items matched: 1651]
# Type: Helios: 2000 [total items matched: 2]
# generation: 1: 1 [total items matched: 1653]
# sequence: 1: 5000 [total items matched: 1]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_33701/3540908384.py in <module>
#     145 # Convert CSV to Excel file format
#     146 read_file = pd.read_csv (r"{}.csv".format(collection_name))
# --> 147 read_file.to_excel (r'{}.xlsx'.format(collection_name), index = None, header=True) #will need to change the file name to something that is based on the collection name
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2279             inf_rep=inf_rep,
#    2280         )
# -> 2281         formatter.write(
#    2282             excel_writer,
#    2283             sheet_name=sheet_name,
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     832             # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     833             # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 834             writer = ExcelWriter(  # type: ignore[abstract]
#     835                 writer, engine=engine, storage_options=storage_options
#     836             )
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/excel/_openpyxl.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      46     ):
#      47         # Use the openpyxl module as the Excel writer.
# ---> 48         from openpyxl.workbook import Workbook
#      49
#      50         engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
print("Getting dynamic api link. Please wait ...")
link = "https://solanart.io/collections/{}".format(collection_name)
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.193 Safari/537.36'
}
try:
    resp1 = requests.get(link, headers=headers).text
except:
    print("Failed to open {}".format(link))

custom_js_link = "https://solanart.io" + \
    resp1.split('<script src="')[1].split('"')[0]
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.193 Safari/537.36'
}
try:
    resp2 = requests.get(custom_js_link, headers=headers).text
except:
    print("Failed to open {}".format(link))

# Parse the API link from the javascript code
api_link = re.findall(r'REACT_APP_API_NETWORK:"(.+?)"', resp2)[0]

link = "{}/nft_for_sale?collection={}".format(api_link, collection_name)
# HTTP header to make sure the website accepts our request
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.193 Safari/537.36'
}
# make the request from the website and convert the data into a JSON file
try:
    # print(resp) will show all the data collected
    resp3 = requests.get(link, headers=headers).json()
except:
    print("Failed to open {}".format(link))
# Out:
# Getting dynamic api link. Please wait ...

# %%
resp1

# %%
resp2

# %%
resp3

# %%
link1 = 'https://jmccmlyu33.medianetwork.cloud/nft_for_sale?collection=aurory'

# %%
link2 = 'https://ksfclzmasu.medianet.work/nft_for_sale?collection=aurory'

# %%
for i in range(100):
    resp4 = requests.get(link1, headers=headers).json()

# %%
resp4

# %%
for i in range(100):
    resp5 = requests.get(link2, headers=headers).json()

# %%
resp5
